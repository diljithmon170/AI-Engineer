# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This is a sample document about AI.",
        "LangChain makes it easy to work with LLMs."
        ],
        ids=["doc1", "doc2"]
    )
# Out:
# C:\Users\dilji\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:53<00:00, 1.56MiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['doc1', 'doc2'],
#  'embeddings': None,
#  'documents': ['This is a sample document about AI.',
#   'LangChain makes it easy to work with LLMs.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
document = collection.get(ids=["doc1"])
document
# Out:
# {'ids': ['doc1'],
#  'embeddings': None,
#  'documents': ['This is a sample document about AI.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts=["Query is about AI"],
    n_results=2
)
results
# Out:
# {'ids': [['doc1', 'doc2']],
#  'embeddings': None,
#  'documents': [['This is a sample document about AI.',
#    'LangChain makes it easy to work with LLMs.']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[0.5734418034553528, 2.0058505535125732]]}
